# %%
import pandas as pd

# %%
data_filename ='/content/Cyber-Threat-Intelligence-Custom-Data_new_processed.csv'

# %%
df = pd.read_csv(data_filename)

# %%
df
# Out:
#         id                                               text  \
# 0      249  A cybersquatting domain save-russia[.]today is...
# 1    14309  Like the Android Maikspy, it first sends a not...
# 2    13996  While analyzing the technical details of this ...
# 3    13600  (Note that Flash has been declared end-of-life...
# 4    14364  Figure 21. Connection of Maikspy variants to 1...
# ..     ...                                                ...
# 471   5279  Cyclops Blink, an advanced modular botnet that...
# 472   1543   Sofacy Group has been associated with many at...
# 473  13595  The plugin has been designed to drop multiple ...
# 474   2368  We have uncovered a cyberespionage campaign be...
# 475  14267  Based on the analysis of samples that were las...
#
#                                              relations  \
# 0    [{'from_id': 44658, 'id': 9, 'to_id': 44659, '...
# 1    [{'from_id': 48531, 'id': 445, 'to_id': 48532,...
# ...

# %%
df.columns
# Out:
# Index(['id', 'text', 'relations', 'diagnosis', 'solutions', 'id_1', 'label_1',
#        'start_offset_1', 'end_offset_1', 'id_2', 'label_2', 'start_offset_2',
#        'end_offset_2', 'id_3', 'label_3', 'start_offset_3', 'end_offset_3'],
#       dtype='object')

# %%
len(df)
# Out:
# 476

# %%
df.describe()
# Out:
#                  id          id_1  start_offset_1  end_offset_1          id_2  \
# count    476.000000    476.000000      476.000000    476.000000    476.000000
# mean    4672.651261  41037.617647       63.703782     77.376050  43544.147059
# std     4178.163473  16171.093234       62.684830     64.789955  13357.982594
# min      105.000000    377.000000        0.000000      4.000000    771.000000
# 25%     2023.500000  45168.250000       16.000000     28.000000  45615.500000
# 50%     3442.500000  48220.500000       46.000000     58.500000  48311.000000
# 75%     4821.000000  50081.000000       93.250000    110.000000  50062.250000
# max    14408.000000  51779.000000      428.000000    451.000000  51777.000000
#
#        start_offset_2  end_offset_2          id_3  start_offset_3  \
# count      476.000000    476.000000    329.000000      329.000000
# mean        81.987395     98.976891  45473.595745      106.367781
# std         68.756656     71.263909  10795.967067       88.730761
# ...

# %%
numerics = ['int16','int32','int64','float16','float32','float64']

numeric_df = df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 10

# %%
missing_percentages = df.isna().sum( ).sort_values(ascending=False) / len(df )
missing_percentages
# Out:
# end_offset_3      0.308824
# start_offset_3    0.308824
# label_3           0.308824
# id_3              0.308824
# diagnosis         0.002101
# id_2              0.000000
# end_offset_2      0.000000
# start_offset_2    0.000000
# label_2           0.000000
# id                0.000000
# text              0.000000
# start_offset_1    0.000000
# label_1           0.000000
# id_1              0.000000
# solutions         0.000000
# relations         0.000000
# end_offset_1      0.000000
# dtype: float64

# %%
missing_percentages[missing_percentages !=0]
# Out:
# end_offset_3      0.308824
# start_offset_3    0.308824
# label_3           0.308824
# id_3              0.308824
# diagnosis         0.002101
# dtype: float64
# end_offset_3      0.308824
# start_offset_3    0.308824
# label_3           0.308824
# id_3              0.308824
# diagnosis         0.002101
# dtype: float64

# %%
type(missing_percentages)
# Out:
# pandas.core.series.Series

# %%
df.columns
# Out:
# Index(['id', 'text', 'relations', 'diagnosis', 'solutions', 'id_1', 'label_1',
#        'start_offset_1', 'end_offset_1', 'id_2', 'label_2', 'start_offset_2',
#        'end_offset_2', 'id_3', 'label_3', 'start_offset_3', 'end_offset_3'],
#       dtype='object')

# %%
df.start_offset_1
# Out:
# 0        2
# 1        9
# 2      188
# 3       62
# 4      163
#       ...
# 471      0
# 472    221
# 473     73
# 474    185
# 475    128
# Name: start_offset_1, Length: 476, dtype: int64

# %%
 df.end_offset_1
# Out:
# 0       16
# 1       17
# 2      194
# 3       79
# 4      191
#       ...
# 471     13
# 472    227
# 473     79
# 474    190
# 475    149
# Name: end_offset_1, Length: 476, dtype: int64

# %%
df.diagnosis
# Out:
# 0      The diagnosis is a cyber attack that involves ...
# 1      The diagnosis is that the entity identified as...
# 2      Diagnosis: APT37/Reaper/Group 123 is responsib...
# 3      The diagnosis is a malware infection. The enti...
# 4      The diagnosis is that Maikspy malware variants...
#                              ...
# 471    Diagnosis: WatchGuard Firebox devices have bee...
# 472    The diagnosis is that Sofacy Group is a threat...
# 473    The infrastructure has been targeted by an att...
# 474    Diagnosis: Earth Baku, a known APT group with ...
# 475    The diagnosis is that the Maikspy variant is a...
# Name: diagnosis, Length: 476, dtype: object

# %%
lf = df.label_1.unique()
lf[:100]
# Out:
# array(['attack-pattern', 'SOFTWARE', 'threat-actor', 'TIME', 'URL',
#        'location', 'vulnerability', 'tools', 'malware', 'campaign',
#        'identity', 'REGISTRYKEY', 'FILEPATH', 'Infrastucture', 'url',
#        'hash', 'IPV4'], dtype=object)
# array(['attack-pattern', 'SOFTWARE', 'threat-actor', 'TIME', 'URL',
#        'location', 'vulnerability', 'tools', 'malware', 'campaign',
#        'identity', 'REGISTRYKEY', 'FILEPATH', 'Infrastucture', 'url',
#        'hash', 'IPV4'], dtype=object)

# %%
 number_attack = df.label_1.value_counts()
 number_attack
# Out:
# label_1
# malware           141
# threat-actor       68
# attack-pattern     44
# identity           37
# vulnerability      35
# SOFTWARE           25
# location           23
# campaign           20
# tools              19
# TIME               17
# FILEPATH           15
# hash               14
# Infrastucture       7
# url                 6
# URL                 3
# REGISTRYKEY         1
# IPV4                1
# Name: count, dtype: int64

# %%
number_attack[:10]
# Out:
# label_1
# malware           141
# threat-actor       68
# attack-pattern     44
# identity           37
# vulnerability      35
# SOFTWARE           25
# location           23
# campaign           20
# tools              19
# TIME               17
# Name: count, dtype: int64

# %%
number_attack[:10].plot(kind='barh')
# Out:
# <Axes: ylabel='label_1'>

# %%
import seaborn as sns
sns.set_style("darkgrid")

# %%
list(number_attack)
# Out:
# [141, 68, 44, 37, 35, 25, 23, 20, 19, 17, 15, 14, 7, 6, 3, 1, 1]

# %%
sns.histplot(number_attack)
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %%
high_attack = number_attack[number_attack>100]
low_attack = number_attack[number_attack>50]

# %%
len(high_attack)
# Out:
# 1

# %%
len(low_attack)
# Out:
# 2

# %%
sns.distplot(number_attack)
# Out:
# <ipython-input-46-ce3f1719fd3c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(number_attack)
# <Axes: xlabel='count', ylabel='Density'>

# %%
sns.histplot(high_attack,log_scale=True)
# Out:
# <Axes: xlabel='count', ylabel='Count'>

# %%
number_attack[number_attack == 1]
# Out:
# label_1
# REGISTRYKEY    1
# IPV4           1
# Name: count, dtype: int64

# %%
df.solutions
# Out:
# 0      1. Implementing DNS filtering to block access ...
# 1      1. Implementing a robust anti-malware software...
# 2      1. Implementing advanced threat detection tech...
# 3      1. Implementing a robust antivirus software th...
# 4      1. Implementing a robust firewall system that ...
#                              ...
# 471    1. Update WatchGuard Firebox devices with the ...
# 472    1. Implementing a comprehensive threat intelli...
# 473    1. Implementing a web application firewall (WA...
# 474    1. Implementing network segmentation to limit ...
# 475    1. Educate users about the risks of downloadin...
# Name: solutions, Length: 476, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
sns.boxplot(x='label_1', y='solutions', data=df)
# Out:
# <Axes: xlabel='label_1', ylabel='solutions'>

# %%
sns.scatterplot()
# Out:
# <Axes: xlabel='start_offset_1', ylabel='end_offset_1'>
